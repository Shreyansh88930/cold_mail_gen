# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0,
    groq_api_key="YOUR_GROQ_API_KEY",
    model_name="openai/gpt-oss-120b"
)

response = llm.invoke("How much time will the IRFC share price take to reach 180 inr")
print(response.content)
# Out:
# I can provide you with some general information about the Indian Railway Finance Corporation (IRFC) and its stock performance. However, predicting the exact time it will take for the IRFC share price to reach 180 INR is challenging and subject to various market and economic factors.
#
# To provide a more informed answer, I'll need to consider the following:
#
# 1. **Current share price**: Please provide the current share price of IRFC.
# 2. **Historical performance**: I'll need to analyze the historical stock performance of IRFC to understand its growth pattern and volatility.
# 3. **Market trends**: I'll consider the overall market trends, sector performance, and economic indicators that may impact the stock price.
# 4. **Assumptions**: I'll need to make some assumptions about the growth rate and volatility of the stock price.
#
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

# Set a User-Agent (optional, helps avoid blocking)
loader = WebBaseLoader("https://careers.airindia.com/job/Gurugram-Manager-Procurement/45631244/")

# This returns a list of Documents
docs = loader.load()

# Access first document's content
page_data = docs[0].page_content
print(page_data)  # print first 1000 chars
# Out:
# Manager - Procurement Job Details | Air India Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     By continuing to use and navigate this website, you are agreeing to the use of cookies.
#
#
#
#                 Accept
#
#                 Close
#
#
#
#
#
#
# Press Tab to Move to Skip to Content Link
# Skip to main content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# View Profile
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# View Profile
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# View Profile
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search by Keyword
#
#
#
#
# Search by Location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Clear
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Select how often (in days) to receive an alert:
#
#
#
#  Create Alert
#
#
#
#
#
#
#
# ×
#
#
#
# Select how often (in days) to receive an alert:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate
prompt_extract = PromptTemplate.from_template(
"""
### SCRAPED TEXT FROM WEBSITE:
{page_data}
### INSTRUCTION:
The scraped text is from the career's page of a website.
Your job is to extract the job postings and return them in JSON format containing the
following keys: `role`, `experience`,`skills` and `description`.
Only return the valid JSON.
VALID JSON (NO PREAMBLE):
"""
)
chain_extract= prompt_extract | llm
res = chain_extract.invoke(input={'page_data' :page_data})
print(res. content)
# Out:
# ```json
# [
#   {
#     "role": "Manager - Procurement",
#     "experience": {
#       "min": "6-7 years",
#       "desired": "10+ year of Industry experience in Supply Chain is preferable (Warehouse and Logistics, Repair Management, Material Planning / Support & Inventory Control, Technical Purchasing), ideally within the aviation industry."
#     },
#     "skills": [
#       "Technical Procurement",
#       "Strategic Cost Control",
#       "Engineering Support",
#       "Operational Leadership",
#       "Material Management",
#       "Resource Allocation",
#       "Reliability Standards",
#       "Conflict Resolution"
#     ],
#     "description": {
#       "jobPurpose": "Effectively control Purchasing of Aircraft Spares, Buyer Furnished Equipment (BFE), Tools, Consumables and Modification/Retrofit Materials required by Engineering in order to support the business to maintain desired Aircraft dispatch reliability standards.",
#       "keyAccountabilities": [
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser
json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Manager - Procurement',
#   'experience': {'min': '6-7 years',
#    'desired': '10+ year of Industry experience in Supply Chain is preferable (Warehouse and Logistics, Repair Management, Material Planning / Support & Inventory Control, Technical Purchasing), ideally within the aviation industry.'},
#   'skills': ['Technical Procurement',
#    'Strategic Cost Control',
#    'Engineering Support',
#    'Operational Leadership',
#    'Material Management',
#    'Resource Allocation',
#    'Reliability Standards',
#    'Conflict Resolution'],
#   'description': {'jobPurpose': 'Effectively control Purchasing of Aircraft Spares, Buyer Furnished Equipment (BFE), Tools, Consumables and Modification/Retrofit Materials required by Engineering in order to support the business to maintain desired Aircraft dispatch reliability standards.',
#    'keyAccountabilities': ['Purchasing and Procurement Management',
#     'Supply Chain Performance Management',
# ...

# %%
import pandas as pd
df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
# Define a job with skills
job = {
    "title": "Software Engineer",
    "skills": "Python, React, SQL"
}

# Query ChromaDB
results = collection.query(
    query_texts=[job["skills"]],  # must be a list of strings
    n_results=2
)

# Extract metadata (links)
links = results.get("metadatas", [])
print(links)
# Out:
# [[{'links': 'https://example.com/python-portfolio'}, {'links': 'https://example.com/react-portfolio'}]]

# %%
job = json_res
job['skills']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 job = json_res
# ----> 2 job['skills']
#
# TypeError: list indices must be integers or slices, not str

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Enhance Procurement Efficiency with AtliQ's Automated Solutions
#
# Dear Hiring Manager,
#
# I came across the job description for a Manager - Procurement at your esteemed organization, and I was impressed by the role's focus on strategic cost control, operational leadership, and material management. As a Business Development Executive at AtliQ, I believe our company can help you streamline your procurement processes and achieve your business goals.
#
# At AtliQ, we specialize in developing tailored solutions that facilitate seamless integration of business processes through automated tools. Our expertise in AI and software consulting has empowered numerous enterprises to scale their operations, optimize processes, reduce costs, and enhance overall efficiency. I'd like to highlight our capabilities in technical procurement, engineering support, and resource allocation, which align perfectly with your requirements.
#
# ...
